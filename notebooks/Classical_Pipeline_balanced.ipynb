# %% [markdown]
# <a href="https://colab.research.google.com/github/zohrehasadi00/automatic_image_analysis/blob/main/notebooks/Classical_Pipeline_balanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fundamental setup

# %%
# import collection
import os
import pickle
import cv2
from pathlib import Path

import pandas  as pd
import numpy   as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.mixture         import GaussianMixture
from sklearn.metrics         import roc_curve, auc, classification_report, confusion_matrix
from sklearn.calibration     import calibration_curve
from scipy.sparse            import find


import torch
from torch.utils.data import Dataset, DataLoader
from torchvision      import transforms
from PIL import Image

# %%
#set seed for reproducibility
random_state = 42
torch.manual_seed(random_state)
np.random.seed(random_state)

# %%
# connect Drive for data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# set project_dir
project_dir = Path('/content/drive/MyDrive/AIA_SkinLesion_Projekt')

# %%
#path to image data
data_raw =[
    str(project_dir / 'data' / 'raw' / 'HAM10000_images_part_1'),
    str(project_dir / 'data' / 'raw' / 'HAM10000_images_part_2')
    ]

# load metadata
csv_path    = project_dir / 'HAM10000_metadata_converted.csv'
df_metadata = pd.read_csv(csv_path)

#load splits
csv_train = project_dir / 'splits' / 'train_balanced.csv'
df_train  = pd.read_csv(csv_train)

csv_test = project_dir / 'splits' / 'test.csv'
df_test  = pd.read_csv(csv_test)

csv_val = project_dir / 'splits' / 'val.csv'
df_val  = pd.read_csv(csv_val)

#load histogram
feature_dir = project_dir / 'histogram'

#Train-Set laden
X_train   = np.load(os.path.join(feature_dir, 'train_balanced_histograms.npy'))
y_train   = np.load(os.path.join(feature_dir, 'train_balanced_labels.npy'))
ids_train = np.load(os.path.join(feature_dir, 'train_balanced_ids.npy'))

#Validation-Set laden
X_val   = np.load(os.path.join(feature_dir, 'val_histograms.npy'))
y_val   = np.load(os.path.join(feature_dir, 'val_labels.npy'))
ids_val = np.load(os.path.join(feature_dir, 'val_ids.npy'))

#Test-Set laden
X_test   = np.load(os.path.join(feature_dir, 'test_histograms.npy'))
y_test   = np.load(os.path.join(feature_dir, 'test_labels.npy'))
ids_test = np.load(os.path.join(feature_dir, 'test_ids.npy'))

# %% [markdown]
# # Data preprocessing for classical pipeline

# %%
# define image tranformations for train and test/validation set
train_transforms_classical = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

test_transforms_classical = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

## function for searching images from drive
def find_image_path(img_id, directories):
    img_name = img_id + '.jpg'
    for directory in directories:
        path = os.path.join(directory, img_name)
        if os.path.exists(path):
            return path
    return None

# Dataset class
class SkinDataset(Dataset):
    def __init__(self, dataframe, img_dirs, transform=None):
        self.data      = dataframe.reset_index(drop=True)
        self.img_dirs  = img_dirs
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_id   = self.data.loc[idx, 'image_id']
        img_name = img_id + '.jpg'
        img_path = None

        # search in both folders (part 1&2) for the image
        img_path = find_image_path(img_id, self.img_dirs)

        if img_path is None:
            raise FileNotFoundError(f"Image {img_name} not found!")

        image = Image.open(img_path).convert('RGB')
        label = self.data.loc[idx, 'label']

        if self.transform:
            image = self.transform(image)

        # PyTorch expects labels as Float for binary loss (BCEWithLogitsLoss)
        return image, torch.tensor(label, dtype=torch.float32), img_id



# create data sets
train_dataset = SkinDataset(df_train, data_raw, transform=train_transforms_classical)
val_dataset   = SkinDataset(df_val, data_raw, transform=test_transforms_classical)
test_dataset  = SkinDataset(df_test, data_raw, transform=test_transforms_classical)

# %%
## convert RGB to HSV
def tensor_to_hsv(tensor):
    # Tensor (3, H, W) → NumPy (H, W, 3) in RGB
    img_np    = tensor.numpy().transpose(1, 2, 0)
    img_uint8 = (img_np * 255).astype(np.uint8)

    # RGB → HSV
    img_hsv = cv2.cvtColor(img_uint8, cv2.COLOR_RGB2HSV)
    return img_hsv  # shape: (H, W, 3), values: H[0-179], S[0-255], V[0-255]

def compute_hsv_histogram(img_hsv, bins=32):
    hist_h = cv2.calcHist([img_hsv], [0], None, [bins], [0, 180])
    hist_s = cv2.calcHist([img_hsv], [1], None, [bins], [0, 256])
    hist_v = cv2.calcHist([img_hsv], [2], None, [bins], [0, 256])

    # normalize and flatten -> one feature-vector per image
    hist = np.concatenate([hist_h, hist_s, hist_v], axis=0).flatten()
    return hist / hist.sum()

## function for plotting a HSV-histogram from a single image
def plot_hsv_histogram(hist, bins=32):

    #as compute_hsv_histograms return an array with shape (96,) this must be split into 3 channels
    hist_h = hist[:bins]
    hist_s = hist[bins:bins*2]
    hist_v = hist[bins*2:]

    fig, axes = plt.subplots(1, 3, figsize=(15, 4))
    for ax, h, name, color in zip(axes,
                                   [hist_h, hist_s, hist_v],
                                   ['Hue', 'Saturation', 'Value'],
                                   ['red', 'blue', 'gray']):
        ax.bar(range(bins), h, color=color, alpha=0.7)
        ax.set_title(name)
        ax.set_xlabel('bin')
        ax.set_ylabel('Frequency')

    plt.tight_layout()
    plt.show()

# %%
#example histogram
image, label, img_id = train_dataset[42]
img_hsv = tensor_to_hsv(image)
hist = compute_hsv_histogram(img_hsv)
print(f"img id {img_id}")
plot_hsv_histogram(hist)
# Out:
# img id ISIC_0031164

# %%
#compute all histograms
# all_histograms = []
# all_labels = []

#calculate histogram for each image from training data
# for idx in range(len(train_dataset)):
#     if idx%1000 == 0: print(idx)
#     image, label, img_id = train_dataset[idx]
#     img_hsv = tensor_to_hsv(image)
#     hist = compute_hsv_histogram(img_hsv)
#     all_histograms.append(hist)
#     all_labels.append(label.item())

# all_histograms = np.array(all_histograms)
# all_labels = np.array(all_labels)

# new histogram dir
feature_dir = project_dir / 'histogram'
os.makedirs(feature_dir, exist_ok=True)

def extract_and_save_features(dataset, split_name):
    print(f"start {split_name} (in total {len(dataset)} img)...")

    histograms = []
    labels     = []
    img_ids    = []

    for idx in range(len(dataset)):
        if idx % 1000 == 0 and idx > 0:
            print(f"  ... {idx} img.")

        image, label, img_id = dataset[idx]

        img_hsv = tensor_to_hsv(image)
        hist    = compute_hsv_histogram(img_hsv)

        histograms.append(hist)
        labels.append(label.item())
        img_ids.append(img_id)

    histograms = np.array(histograms)
    labels     = np.array(labels)
    img_ids    = np.array(img_ids)

    np.save(os.path.join(feature_dir, f'{split_name}_histograms.npy'), histograms)
    np.save(os.path.join(feature_dir, f'{split_name}_labels.npy'), labels)
    np.save(os.path.join(feature_dir, f'{split_name}_ids.npy'), img_ids)

    print(f" {split_name} saved!\n")

extract_and_save_features(train_dataset, "train_balanced")
extract_and_save_features(val_dataset, "val")
extract_and_save_features(test_dataset, "test")
# Out:
# start train_balanced (in total 2300 img)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12704/3735492690.py in <cell line: 0>()
#      49     print(f" {split_name} saved!\n")
#      50
# ---> 51 extract_and_save_features(train_dataset, "train_balanced")
#      52 extract_and_save_features(val_dataset, "val")
#      53 extract_and_save_features(test_dataset, "test")
#
# /tmp/ipykernel_12704/3735492690.py in extract_and_save_features(dataset, split_name)
#      30             print(f"  ... {idx} img.")
#      31
# ---> 32         image, label, img_id = dataset[idx]
#      33
#      34         img_hsv = tensor_to_hsv(image)
#
# /tmp/ipykernel_12704/1787910517.py in __getitem__(self, idx)
#      40             raise FileNotFoundError(f"Image {img_name} not found!")
#      41
# ---> 42         image = Image.open(img_path).convert('RGB')
# ...

# %%
print("--- data controle ---")
print(f"shape histogram: {X_train.shape}")
print(f"shape label:      {y_train.shape}")
print(f"shape id:         {ids_train.shape}")

print("\n--- sample (first img) ---")
print(f"img id:    {ids_train[0]}")
print(f"label:   {y_train[0]} (0 = benign, 1 = mel)")
print(f"color values: {X_train[0][:96]} ...")

# --- Exact Lookup Sanity Check ---

def verify_lookup(df_csv, ids_npy, labels_npy, split_name):
    # 1. Make CSV easily searchable (set 'image_id' as the index)
    csv_lookup = df_csv.set_index('image_id')['label']

    # 2. Take IDs from NPY data and look up their corresponding labels in the CSV
    found_csv_labels = pd.Series(ids_npy).map(csv_lookup)

    # 3. Compare original NPY labels with the labels found in the CSV
    errors = (labels_npy != found_csv_labels).sum()

    # 4. Print status
    status = "PERFECT" if errors == 0 else f"{errors} ERRORS"
    print(f"{split_name:<12} | Checked: {len(ids_npy):<5} | Status: {status}")

# Run the explicit lookup check for all splits
verify_lookup(df_train, ids_train, y_train, "Train")
verify_lookup(df_val, ids_val, y_val, "Validation")
verify_lookup(df_test, ids_test, y_test, "Test")

print(f"img id:    {ids_train[42]}")
print(f"label:     {y_train[42]} (0 = benign, 1 = malignant)")
plot_hsv_histogram(X_train[42])
# Out:
# --- data controle ---
# shape histogram: (2300, 96)
# shape label:      (2300,)
# shape id:         (2300,)
#
# --- sample (first img) ---
# img id:    ISIC_0025400
# label:   0.0 (0 = benign, 1 = mel)
# color values: [0.0000000e+00 6.6432822e-06 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  0.0000000e+00 0.0000000e+00 6.6432822e-06 0.0000000e+00 0.0000000e+00
#  0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  2.1258503e-04 8.7691325e-04 3.0545812e-02 6.1045121e-02 6.4858362e-02
#  7.0106559e-02 4.0696748e-02 2.6539912e-02 1.5771152e-02 1.3379571e-02
#  9.1145830e-03 1.7272534e-04 6.6432822e-06 0.0000000e+00 1.3751595e-03
#  9.2082538e-02 1.4244527e-01 3.2452434e-02 1.6302615e-02 9.6792625e-03
#  6.0121706e-03 4.8230230e-03 4.7632335e-03 5.5737137e-03 5.0422512e-03
#  2.8101085e-03 2.6971726e-03 2.2321430e-03 1.0762117e-03 1.0496386e-03
# ...

# %% [markdown]
# # GMM with EM

# %%
X_train_benign   = X_train[y_train == 0]
X_train_melanoma = X_train[y_train == 1]

print(f"Number of benign samples for training:   {X_train_benign.shape[0]}")
print(f"Number of malignant samples for training: {X_train_melanoma.shape[0]}")

print(" Training arc")

bic_melanoma = []
bic_benign   = []

K_range = range(1, 11)

for K in K_range:
    print(f"\nTraining GMM for benign samples with K={K} components...")
    gmm_benign = GaussianMixture(n_components=K, random_state=random_state, covariance_type='full') # 'full', 'tied', 'diag', 'spherical'
    gmm_benign.fit(X_train_benign) #fit = EM
    bic_benign.append(gmm_benign.bic(X_train_benign))
    # print(f"  Converged: {gmm_benign.converged_}")
    # print(f"  BIC: {bic_benign[K-1]:.2f}")
    # print(f"  AIC: {gmm_benign.aic(X_train_benign):.2f}")

    print(f"Training GMM for malignant samples with K={K} components...")
    gmm_melanoma = GaussianMixture(n_components=K, random_state=random_state, covariance_type='full')
    gmm_melanoma.fit(X_train_melanoma)
    bic_melanoma.append(gmm_melanoma.bic(X_train_melanoma))
    # print(f"  Converged: {gmm_melanoma.converged_}")
    # print(f"  BIC: {bic_melanoma[K-1]:.2f}")
    # print(f"  AIC: {gmm_melanoma.aic(X_train_melanoma):.2f}")

min_K_benign   = np.argmin(bic_benign) + 1
min_K_melanoma = np.argmin(bic_melanoma) + 1

print(f"Opt K for benign: {min_K_benign}")
print(f"Opt K for malignant:  {min_K_melanoma}")

print("trianig done")

plt.figure(figsize=(10, 5))

# Plot for benign
plt.plot(K_range, bic_benign, marker='o', color='blue', label=f'Benign (Min: K={min_K_benign})')

# Plot for melanom
plt.plot(K_range, bic_melanoma, marker='o', color='red', label=f'Malignant (Min: K={min_K_melanoma})')

plt.title('BIC-value to set K')
plt.xlabel('# (K)')
plt.ylabel('BIC-value (smaller better)')
plt.xticks(K_range)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Number of benign samples for training:   1150
# Number of malignant samples for training: 1150
#  Training arc
#
# Training GMM for benign samples with K=1 components...
# Training GMM for malignant samples with K=1 components...
#
# Training GMM for benign samples with K=2 components...
# Training GMM for malignant samples with K=2 components...
#
# Training GMM for benign samples with K=3 components...
# Training GMM for malignant samples with K=3 components...
#
# Training GMM for benign samples with K=4 components...
# Training GMM for malignant samples with K=4 components...
#
# Training GMM for benign samples with K=5 components...
# Training GMM for malignant samples with K=5 components...
#
# Training GMM for benign samples with K=6 components...
# Training GMM for malignant samples with K=6 components...
#
# Training GMM for benign samples with K=7 components...
# Training GMM for malignant samples with K=7 components...
#
# ...

# %% [markdown]
# ### Bayesian Decision Rule with Asymmetric Loss
#
# First, we load the optimal GMMs using the best $K$ components found by your BIC analysis, calculate the log-likelihoods, and apply the asymmetric decision threshold.
#
# Since false negatives (missing melanoma) are much more costly than false positives, we define a cost ratio:
#
# $$\text{Cost Ratio} = \frac{\text{Cost of False Negative}}{\text{Cost of False Positive}}$$

# %%
# min_K_benign and min_K_melanoma were calculated in previous cell, run previous cell if it throws an error
print(f"Refitting final GMMs with optimal K: Benign={min_K_benign}, Malignant={min_K_melanoma}")

# Train final models
gmm_benign_final = GaussianMixture(n_components=min_K_benign, random_state=random_state, covariance_type='full')
gmm_benign_final.fit(X_train_benign)

gmm_melanoma_final = GaussianMixture(n_components=min_K_melanoma, random_state=random_state, covariance_type='full')
gmm_melanoma_final.fit(X_train_melanoma)

# Compute log-likelihoods on Validation set
log_lik_benign   = gmm_benign_final.score_samples(X_val)
log_lik_melanoma = gmm_melanoma_final.score_samples(X_val)

# Compute Posterior Probability using Bayes' Theorem
# Prior probabilities based on training class distribution
prior_benign   = len(X_train_benign)   / len(X_train)
prior_melanoma = len(X_train_melanoma) / len(X_train)

# Shift log-likelihoods by priors to avoid underflow before exponentiation
likelihood_prior_b = np.exp(log_lik_benign)   * prior_benign
likelihood_prior_m = np.exp(log_lik_melanoma) * prior_melanoma

# Posterior probability of being melanoma: P(Melanoma | x)
posterior_melanoma = likelihood_prior_m / (likelihood_prior_b + likelihood_prior_m)

# Asymmetric Loss Thresholding
# Standard threshold is 0.5. If False Negatives are 5x more costly than False Positives:
cost_fn = 5.0
cost_fp = 1.0
asymmetric_threshold = cost_fp / (cost_fn + cost_fp) # e.g., 1 / 6 ≈ 0.167

y_pred_standard   = (posterior_melanoma >= 0.5).astype(int)
y_pred_asymmetric = (posterior_melanoma >= asymmetric_threshold).astype(int)

print(f"Standard Threshold (0.5) Malignant predictions: {y_pred_standard.sum()}")
print(f"Asymmetric Threshold ({asymmetric_threshold:.3f}) Malignant predictions: {y_pred_asymmetric.sum()}")
# Out:
# Refitting final GMMs with optimal K: Benign=2, Malignant=2
# Standard Threshold (0.5) Malignant predictions: 457
# Asymmetric Threshold (0.167) Malignant predictions: 466

# %% [markdown]
# ### Saving the trained Model
# This cell saves the trained GMMs and the priors to your Google Drive so you can reload them later without retraining.

# %%
# Define the file path
model_save_path = project_dir / 'gmm_models.pkl'

# Pack the models and priors into a dictionary
model_data = {
    'gmm_benign':     gmm_benign_final,
    'gmm_melanoma':   gmm_melanoma_final,
    'prior_benign':   prior_benign,
    'prior_melanoma': prior_melanoma
}

# Save to Drive
with open(model_save_path, 'wb') as f:
    pickle.dump(model_data, f)

print(f"Modell erfolgreich gespeichert unter: {model_save_path}")
# Out:
# Modell erfolgreich gespeichert unter: /content/drive/MyDrive/AIA_SkinLesion_Projekt/gmm_models.pkl

# %% [markdown]
# ### Loading the Model (Optional)
# If you restart the notebook, you can skip the training cells and use this code to load the models directly.

# %%
with open(project_dir / 'gmm_models.pkl', 'rb') as f:
    loaded_data = pickle.load(f)

gmm_benign_final   = loaded_data['gmm_benign']
gmm_melanoma_final = loaded_data['gmm_melanoma']
prior_benign       = loaded_data['prior_benign']
prior_melanoma     = loaded_data['prior_melanoma']
print("Modell erfolgreich geladen!")
# Out:
# Modell erfolgreich geladen!

# %% [markdown]
# ### ROC Curve Evaluation
#
# This snippet generates the ROC curve and computes the Area Under the Curve (AUC) to evaluate the performance of your GMM classifier.

# %%
# Calculate ROC curve metrics
fpr, tpr, thresholds = roc_curve(y_val, posterior_melanoma)
roc_auc = auc(fpr, tpr)

# Plot ROC
plt.figure(figsize=(7, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'GMM Pipeline (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Classical Pipeline')
plt.legend(loc="lower right")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# Print metrics comparing both triage behaviors
print("--- Standard Triage Report (Threshold = 0.5) ---")
print(classification_report(y_val, y_pred_standard, target_names=['Benign', 'Malignant'], digits=4))

print("\n--- Asymmetric Triage Report (Low Threshold for High Safety) ---")
print(classification_report(y_val, y_pred_asymmetric, target_names=['Benign', 'Malignant'],digits=4))
# Out:
# --- Standard Triage Report (Threshold = 0.5) ---
#               precision    recall  f1-score   support
#
#       Benign     0.9674    0.6196    0.7554       815
#    Malignant     0.3217    0.8963    0.4734       164
#
#     accuracy                         0.6660       979
#    macro avg     0.6445    0.7580    0.6144       979
# weighted avg     0.8593    0.6660    0.7082       979
#
#
# --- Asymmetric Triage Report (Low Threshold for High Safety) ---
#               precision    recall  f1-score   support
#
#       Benign     0.9727    0.6123    0.7515       815
#    Malignant     0.3219    0.9146    0.4762       164
#
#     accuracy                         0.6629       979
#    macro avg     0.6473    0.7635    0.6138       979
# weighted avg     0.8637    0.6629    0.7054       979

# %% [markdown]
# ### Calibration Analysis
#
# To address the project's requirement for "calibrated uncertainty," this snippet plots a calibration curve (reliability diagram) to see how closely the GMM's posterior probabilities reflect true real-world frequencies.

# %%
# Compute calibration curve
prob_true, prob_pred = calibration_curve(y_val, posterior_melanoma, n_bins=10)

# Plot Calibration Curve
plt.figure(figsize=(7, 6))
plt.plot(prob_pred, prob_true, marker='o', linewidth=2, label='GMM Classifier')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Perfect Calibration')
plt.xlabel('Mean Predicted Probability (Confidence)')
plt.ylabel('Fraction of Positives (Actual Truth)')
plt.title('Reliability Diagram / Calibration Analysis')
plt.legend(loc="upper left")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ### Final Evaluation on the Test Set
# In this section, we apply the trained GMM models to the unseen test set to evaluate final performance.

# %%
# Size of the test set
print(f"Größe des Test-Sets: {len(X_test)} Samples")

# Compute log-likelihoods on the Test set
log_lik_benign_test   = gmm_benign_final.score_samples(X_test)
log_lik_melanoma_test = gmm_melanoma_final.score_samples(X_test)

# Numerically stable computation of Posterior Probability
# log(P(m|x)) = log(p(x|m)P(m)) - log(p(x|m)P(m) + p(x|b)P(b))
log_num = log_lik_melanoma_test + np.log(prior_melanoma)
log_den = np.log(np.exp(log_lik_melanoma_test + np.log(prior_melanoma) - np.maximum(log_lik_benign_test, log_lik_melanoma_test)) +
                 np.exp(log_lik_benign_test + np.log(prior_benign) - np.maximum(log_lik_benign_test, log_lik_melanoma_test))) + np.maximum(log_lik_benign_test, log_lik_melanoma_test)

# A simpler, often sufficient way for binary cases:
# posterior = 1 / (1 + exp(log_lik_benign + log_prior_benign - log_lik_melanoma - log_prior_melanoma))
log_ratio = (log_lik_benign_test + np.log(prior_benign)) - (log_lik_melanoma_test + np.log(prior_melanoma))
posterior_melanoma_test = 1 / (1 + np.exp(np.clip(log_ratio, -100, 100)))

# Predictions (0.167 from tut)
y_pred_test = (posterior_melanoma_test >= 0.167).astype(int)

# Metrics: ROC and AUC
fpr_test, tpr_test, _ = roc_curve(y_test, posterior_melanoma_test)
roc_auc_test = auc(fpr_test, tpr_test)

plt.figure(figsize=(12, 5))

# Plot ROC
plt.subplot(1, 2, 1)
plt.plot(fpr_test, tpr_test, color='green', lw=2, label=f'Test ROC (AUC = {roc_auc_test:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.title('ROC Curve (Test Set)')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.grid(True, alpha=0.3)

# Plot Confusion Matrix
plt.subplot(1, 2, 2)
cm = confusion_matrix(y_test, y_pred_test)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Benign', 'Malignant'], yticklabels=['Benign', 'Malignant'])
plt.title('Confusion Matrix (Test Set)')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.tight_layout()
plt.show()

# Detailed Classification Report
print("--- Test Set Classification Report ---")
print(classification_report(y_test, y_pred_test, target_names=['Benign', 'Malignant'], digits=4))
# Out:
# Größe des Test-Sets: 1917 Samples
# --- Test Set Classification Report ---
#               precision    recall  f1-score   support
#
#       Benign     0.9502    0.6072    0.7410      1604
#    Malignant     0.2937    0.8371    0.4349       313
#
#     accuracy                         0.6448      1917
#    macro avg     0.6220    0.7221    0.5879      1917
# weighted avg     0.8430    0.6448    0.6910      1917
